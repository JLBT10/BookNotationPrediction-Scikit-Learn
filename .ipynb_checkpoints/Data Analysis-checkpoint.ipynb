# %% [markdown]
# IMPORT MODULES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import unidecode
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from transformer_functions import *

# %% [markdown]
# ### UNDERSTAND THE DATA STRUCTURE - DATA EXPLORATION

# %%
df=pd.read_csv('./datasets/books.csv',on_bad_lines='skip')
df.rename(columns={'  num_pages':'num_pages'},inplace=True)
df.head(3)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
#
#   language_code  num_pages  ratings_count  text_reviews_count  \
# 0           eng        652        2095690               27591
# 1           eng        870        2153167               29221
# 2           eng        352           6333                 244
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1         9/1/2004  Scholastic Inc.
# 2        11/1/2003       Scholastic

# %% [markdown]
# ##### Title
# The title columns contains text and has different entries , a simple encoding will not be of any use for training and prediction. so we will drop that columns for training. but before doing that i will check for doublons so that i can handle them properly. more over it is writted in different language which will render analysis complicated using nltk model.
#
# ##### Authors
# A book can be written by many authors. There is too many authors to do a One Hot Encoding, and if we isolate the authors(by exploding the columns) we will have  a lot of duplicated information which may not be good for the training. So in order to exploit that columns, i'm going to add the average notation of authors as a new variable instead of authors name. The goodread website has a json file 'goodreads_book_authors.json' that contains the average notation of authors and i will be using that json file to add information.
# ##### Average rating
# Average rating is the element to predict. Using that variable to engineer feature might lead to overfitting during training (we will have good result during training but bad  not as good result during testing). I make the choice not to use it.
#
# ##### Isbn,Isbn3,Publisher
# The publisher columns is structure the same as the authors columns. Moreover we can see that Scholastic Inc. and Scholastic is the same publisher, but if we encode Scholastic Inc. will be considered different from Scholastic which is a huge problem, is the columns contains other cases like this one ? we will verify during the Analyses Part.
#
# We could use ISBN or ISBN13 in order to get the digit of the publisher as an ISBN.
# For example : from ISBN13 : 978-0-545-01022-1 we can infer that
# "978" is the ISBN-13 prefix, indicating that it's an ISBN for a book.
# "0" is the group identifier, representing the country or language area of the publisher.
# "545" is the publisher identifier, unique to the publisher.
# "01022" is the publication element identifies the specific publication
# "7" is the check digit, calculated based on the preceding digits to help detect errors.
#
# unfortunately, the publisher identifier and the the publication element(title) can have varying length which makes it difficult to infer with confidence.
# In our dataset that information is not explicitly given to us and we can not deduce it with confidence. for example is the publisher identifier is composed of 1, 2, 3 , or 4 digits ? we can't be sure of that.
#
# ##### language_code, publication_date
# We will study the composition of the language_code
# We will separate the month and the year in order to study teir relation with average notation and authors notation
#
# ##### num_pages, ratings_count, text_reviews_count
# We will definitely use those for our model, one things we will verify during analysis is the correlation between those variables. Do books get a better rating when there is huge ratings or/and text reviews or a lot of pages.
# We will rename ' num_pages' in  'num_pages'.

# %%
#Let's perform a stratify split by average_rating
df['average_ratings_category']=pd.cut(df['average_rating'],bins=[-1,2,3,4,5],labels=['0','1','2','3'])
print(df['average_ratings_category'].value_counts())

#Split the data into train and test.
train, test= train_test_split(df,test_size=0.2,random_state=42,stratify=df['average_ratings_category'])

# Save train and test
train.to_csv('./datasets/train.csv',index=False)
test.to_csv('./datasets/test.csv',index=False)
# Out:
# 2    6285
# 3    4735
# 1      69
# 0      34
# Name: average_ratings_category, dtype: int64

# %% [markdown]
# ##### CLEANING DATA

# %%
train.describe()
# Out:
#              bookID  average_rating        isbn13    num_pages  ratings_count  \
# count   8898.000000     8898.000000  8.898000e+03  8898.000000   8.898000e+03
# mean   21219.130479        3.934554  9.759939e+12   335.397842   1.800366e+04
# std    13117.373827        0.350502  4.418945e+11   242.309805   1.165082e+05
# min        1.000000        0.000000  8.987060e+09     0.000000   0.000000e+00
# 25%    10158.250000        3.770000  9.780345e+12   192.000000   1.020000e+02
# 50%    19910.000000        3.960000  9.780593e+12   297.000000   7.475000e+02
# 75%    31994.750000        4.140000  9.780875e+12   416.000000   4.918750e+03
# max    45641.000000        5.000000  9.789999e+12  6576.000000   4.597666e+06
#
#        text_reviews_count
# count         8898.000000
# mean           531.606541
# std           2566.945935
# min              0.000000
# 25%              9.000000
# 50%             46.000000
# 75%            235.000000
# max          94265.000000

# %% [markdown]
# * The average rating ranges from 0 to 5
# * We can see two issues with num_pages, the min is equal 0 and the maximum of pages is equal to 6576 (both are not normal for a book)
# * ratings_count : We can't have a rating_count of 0 and have an average_rating different from 0

# %%
# Num_pages Analyse
train.sort_values(by ='num_pages', ascending=False)[:5]
# Out:
#        bookID                                           title  \
# 6497    24520  The Complete Aubrey/Maturin Novels (5 Volumes)
# 6802    25587                            The Second World War
# 10906   44613          Remembrance of Things Past (Boxed Set)
# 6          10    Harry Potter Collection (Harry Potter  #1-6)
# 6822    25709                        Summa Theologica  5 Vols
#
#                                                  authors  average_rating  \
# 6497                                     Patrick O'Brian            4.70
# 6802                    Winston S. Churchill/John Keegan            4.45
# 10906  Marcel Proust/C.K. Scott Moncrieff/Frederick A...            4.34
# 6                                           J.K. Rowling            4.73
# 6822                                      Thomas Aquinas            4.12
#
#              isbn         isbn13 language_code  num_pages  ratings_count  \
# 6497   039306011X  9780393060119           eng       6576           1338
# 6802   039541685X  9780395416853           eng       4736           1493
# 10906  0701125594  9780701125592           eng       3400              6
# 6      0439827604  9780439827607           eng       3342          28242
# 6822   0870610635  9780870610639           eng       3020           2734
#
#        text_reviews_count publication_date              publisher  \
# 6497                   81       10/17/2004  W. W. Norton  Company
# 6802                   99         5/9/1986          Mariner Books
# 10906                   1         3/5/1981        Chatto & Windus
# 6                     808        9/12/2005             Scholastic
# 6822                   84         1/1/1981     Christian Classics
#
#       average_ratings_category
# 6497                         3
# 6802                         3
# 10906                        3
# 6                            3
# 6822                         3

# %% [markdown]
# * We can deduce via the title columns that those books with a lot of pages are actually collections or volumes. so we will drop them  as our concerns
# * is to predict the average_rating of a single book, more over it could include redondancy in our training.

# %%
#let's see what a boxplot will tell us about those outliers
plt.figure(figsize=(5,5))
plt.boxplot(train['num_pages'])
plt.ylabel('number of pages')
plt.ylim(0,3000)
plt.show()

# %% [markdown]
# * we have a lot of outliers that are mostly collections, novels and boxes. We will keep all books that have pages > 1000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8898 entries, 9809 to 7830
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   bookID                    8898 non-null   int64
#  1   title                     8898 non-null   object
#  2   authors                   8898 non-null   object
#  3   average_rating            8898 non-null   float64
#  4   isbn                      8898 non-null   object
#  5   isbn13                    8898 non-null   int64
#  6   language_code             8898 non-null   object
#  7   num_pages                 8898 non-null   int64
#  8   ratings_count             8898 non-null   int64
#  9   text_reviews_count        8898 non-null   int64
#  10  publication_date          8898 non-null   object
#  11  publisher                 8898 non-null   object
#  12  average_ratings_category  8898 non-null   category
# dtypes: category(1), float64(1), int64(5), object(6)
# memory usage: 912.6+ KB

# %% [markdown]
# * There are 0 Na in our dataset.
# * The publication date is an object dtype but we will extract the year and the month then convert it to integer.
# * page at 0 will be replace by the mean of pages.

# %%
#Language Analysis
train.language_code.unique()
# Out:
# array(['eng', 'en-US', 'fre', 'ger', 'spa', 'glg', 'en-GB', 'enm', 'jpn',
#        'ita', 'zho', 'por', 'grc', 'en-CA', 'lat', 'mul', 'rus', 'swe',
#        'ale', 'nor', 'gla', 'tur', 'wel', 'msa', 'ara', 'nl'],
#       dtype=object)

# %% [markdown]
# #We are going to regroup 'eng','en-US','en-GB' into 'eng because it stays english

# %%
#Let's write a function that will cload the data and do all the processing --> see books_functions
#train=process_books(train)
process=BooksProcessingTransformer()
authors_notation=AuthorsNotationTransformer()
train=process.transform(train)
train=authors_notation.transform(train)

# %%
train.describe()
# Out:
#              bookID  average_rating        isbn13    num_pages  ratings_count  \
# count   8142.000000     8142.000000  8.142000e+03  8142.000000   8.142000e+03
# mean   21507.018055        3.937459  9.760296e+12   316.773218   1.532988e+04
# std    13090.321901        0.295754  4.380398e+11   176.829829   1.026078e+05
# min        1.000000        1.000000  8.987060e+09     1.000000   1.000000e+00
# 25%    10561.250000        3.770000  9.780345e+12   193.000000   1.060000e+02
# 50%    20739.500000        3.950000  9.780610e+12   293.000000   7.820000e+02
# 75%    32257.750000        4.130000  9.780873e+12   400.000000   5.016250e+03
# max    45641.000000        5.000000  9.789999e+12   999.000000   4.597666e+06
#
#        text_reviews_count         year        month  authors_average_notation
# count         8142.000000  8142.000000  8142.000000                8142.00000
# mean           486.648121  2000.170474     6.541022                   3.94378
# std           2418.627625     8.326035     3.417079                   0.20327
# min              0.000000  1900.000000     1.000000                   2.37000
# 25%              9.000000  1998.000000     4.000000                   3.82000
# 50%             47.000000  2003.000000     7.000000                   3.95000
# 75%            235.000000  2005.000000     9.000000                   4.07000
# max          94265.000000  2020.000000    12.000000                   4.88000

# %% [markdown]
# * Now that the dataset is clean let's do the data analysis

# %% [markdown]
# #### DATA ANALYSIS
#
# Question we want to answers thanks to the data.
#
# Statistical Analysis
# * Study the distribution of features
# * Analysing correlation between features and average_rating
#
# Data Analysis
# * Which authors wrote the most books ?
# * Who are the top 10 highly rated and the bottom 5 poorly rated authors?
# * Did the books with more text reviews or rating count receive higher ratings ?
# * Did the authors with good notation receive higher ratings for their books?
# * How are books distributed across different languages ?

# %% [markdown]
# * Study the distribution of features

# %%
train.hist(figsize=(8,8))
plt.show()

# %% [markdown]
# From the different distribution we can say that :
# * Average ratings is normally distributed
# * ratigns_count, the text_reviews_count and num_pages are left skew

# %% [markdown]
# * Analysing correlation between features and average_rating
# * Did the books with more text reviews or rating count receive higher ratings ?
# * Did the authors with good notation receive higher ratings for their books?

# %%
attributes = ["ratings_count", "text_reviews_count","num_pages",'authors_average_notation']
for x in attributes:
    plt.scatter(train[x],train.average_rating,alpha=0.1)  #Alpha allows us to know where there is concentration of point in the graph

    # Rotation des étiquettes
# Ajouter des titres et des étiquettes d'axe
    plt.xlabel(x)
    plt.ylabel('average_rating')
    #plt.title('Top 10 of authors with the most wwritten book')

    # Afficher le diagramme
    plt.show()

# %%
train.corr()
# Out:
# /var/folders/5q/_mlmv_q11hd3pwylfnll66qr0000gn/T/ipykernel_17483/2189804198.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr()
#                             bookID  average_rating    isbn13  num_pages  \
# bookID                    1.000000       -0.020808  0.005606   0.001115
# average_rating           -0.020808        1.000000  0.002995   0.098645
# isbn13                    0.005606        0.002995  1.000000   0.023458
# num_pages                 0.001115        0.098645  0.023458   1.000000
# ratings_count            -0.063873        0.032696  0.006692   0.039468
# text_reviews_count       -0.071539        0.027505  0.008758   0.048794
# year                      0.023282       -0.044939  0.002566  -0.002175
# month                     0.003994        0.030361 -0.003838   0.014070
# authors_average_notation -0.024468        0.637398 -0.016669   0.020707
#
#                           ratings_count  text_reviews_count      year  \
# bookID                        -0.063873           -0.071539  0.023282
# average_rating                 0.032696            0.027505 -0.044939
# isbn13                         0.006692            0.008758  0.002566
# num_pages                      0.039468            0.048794 -0.002175
# ratings_count                  1.000000            0.866476  0.044592
# text_reviews_count             0.866476            1.000000  0.066464
# year                           0.044592            0.066464  1.000000
# month                         -0.008199           -0.014160  0.037096
# authors_average_notation       0.028677            0.027010 -0.041674
#
#                              month  authors_average_notation
# bookID                    0.003994                 -0.024468
# average_rating            0.030361                  0.637398
# isbn13                   -0.003838                 -0.016669
# num_pages                 0.014070                  0.020707
# ratings_count            -0.008199                  0.028677
# text_reviews_count       -0.014160                  0.027010
# year                      0.037096                 -0.041674
# month                     1.000000                  0.031848
# authors_average_notation  0.031848                  1.000000

# %% [markdown]
# * We can see from the two first graph that the correlation between ratings_count, text_reviews count with average_ratings is not strong. there is a concentration of point around 0. We also see from the correlation table that ratings_count and text_reviews are well correlated around 86%. we can create a feature with those two in order to get a new feature that might be correlated with average_rating.
#
# * The correlation of average ratings with number of pages is not great either , we can hardly affirm that when the number of pages inscreases the notation is better. we also have a concentration of point around 100-500 pages
#
# * The authors average notation show a clear correlation with average_rating 62%. we can also notice a strong concentation of point between 3.5 and 4.5.
#
#
# The common point of those figure is the concentration of points between certain values.
# Performing a regression analysis on this data can be challenging because the model might struggle to capture meaningful patterns. we will transform this regression problem into a classification which might gave us better results. we will be usign the average_ratings_category for the classification.

# %% [markdown]
# ##### Let's Features Engenieer

# %%
feature_eng=AuthorsFeaturesTransformer()
train=feature_eng.transform(train)

dropped_columns=['publication_date','rate_ratings', 'isbn13', 'title','isbn', 'bookID','authors','average_rating','language_code','publisher','authors_split']
col_remove=ColumnRemoverTransformer(dropped_columns)
train=col_remove.transform(train)

# %%
train.corr()
# Out:
#                           num_pages  ratings_count  text_reviews_count  \
# num_pages                  1.000000       0.039468            0.048794
# ratings_count              0.039468       1.000000            0.866476
# text_reviews_count         0.048794       0.866476            1.000000
# average_ratings_category   0.088037       0.020499            0.021794
# year                      -0.002175       0.044592            0.066464
# month                      0.014070      -0.008199           -0.014160
# authors_average_notation   0.020707       0.028677            0.027010
# rate_ratings_authors       0.084742       0.088156            0.076840
#
#                           average_ratings_category      year     month  \
# num_pages                                 0.088037 -0.002175  0.014070
# ratings_count                             0.020499  0.044592 -0.008199
# text_reviews_count                        0.021794  0.066464 -0.014160
# average_ratings_category                  1.000000 -0.044419  0.024098
# year                                     -0.044419  1.000000  0.037096
# month                                     0.024098  0.037096  1.000000
# authors_average_notation                  0.546854 -0.041674  0.031848
# rate_ratings_authors                      0.371738 -0.037309  0.030792
#
#                           authors_average_notation  rate_ratings_authors
# num_pages                                 0.020707              0.084742
# ratings_count                             0.028677              0.088156
# text_reviews_count                        0.027010              0.076840
# average_ratings_category                  0.546854              0.371738
# year                                     -0.041674             -0.037309
# month                                     0.031848              0.030792
# authors_average_notation                  1.000000              0.633168
# rate_ratings_authors                      0.633168              1.000000

# %% [markdown]
# * Thenew feature ingeneer is equal to (1-text-reviews/ratings_count*authors_notation

# %%
train.corr()
# Out:
# /var/folders/5q/_mlmv_q11hd3pwylfnll66qr0000gn/T/ipykernel_17483/2189804198.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr()
#                             bookID  average_rating    isbn13  num_pages  \
# bookID                    1.000000       -0.020808  0.005606   0.001115
# average_rating           -0.020808        1.000000  0.002995   0.098645
# isbn13                    0.005606        0.002995  1.000000   0.023458
# num_pages                 0.001115        0.098645  0.023458   1.000000
# ratings_count            -0.063873        0.032696  0.006692   0.039468
# text_reviews_count       -0.071539        0.027505  0.008758   0.048794
# average_ratings_category -0.022530        0.789819  0.006532   0.088037
# year                      0.023282       -0.044939  0.002566  -0.002175
# month                     0.003994        0.030361 -0.003838   0.014070
# authors_average_notation -0.024468        0.637398 -0.016669   0.020707
# rate_ratings             -0.004762        0.148089  0.006932   0.095164
# rate_ratings_authors     -0.015098        0.441812 -0.003132   0.084742
#
#                           ratings_count  text_reviews_count  \
# bookID                        -0.063873           -0.071539
# average_rating                 0.032696            0.027505
# isbn13                         0.006692            0.008758
# num_pages                      0.039468            0.048794
# ratings_count                  1.000000            0.866476
# text_reviews_count             0.866476            1.000000
# average_ratings_category       0.020499            0.021794
# year                           0.044592            0.066464
# month                         -0.008199           -0.014160
# authors_average_notation       0.028677            0.027010
# rate_ratings                   0.092312            0.079534
# rate_ratings_authors           0.088156            0.076840
#
#                           average_ratings_category      year     month  \
# bookID                                   -0.022530  0.023282  0.003994
# average_rating                            0.789819 -0.044939  0.030361
# isbn13                                    0.006532  0.002566 -0.003838
# num_pages                                 0.088037 -0.002175  0.014070
# ratings_count                             0.020499  0.044592 -0.008199
# text_reviews_count                        0.021794  0.066464 -0.014160
# average_ratings_category                  1.000000 -0.044419  0.024098
# year                                     -0.044419  1.000000  0.037096
# month                                     0.024098  0.037096  1.000000
# authors_average_notation                  0.546854 -0.041674  0.031848
# rate_ratings                              0.114606 -0.020994  0.017176
# rate_ratings_authors                      0.371738 -0.037309  0.030792
#
#                           authors_average_notation  rate_ratings  \
# bookID                                   -0.024468     -0.004762
# average_rating                            0.637398      0.148089
# isbn13                                   -0.016669      0.006932
# num_pages                                 0.020707      0.095164
# ratings_count                             0.028677      0.092312
# text_reviews_count                        0.027010      0.079534
# average_ratings_category                  0.546854      0.114606
# year                                     -0.041674     -0.020994
# month                                     0.031848      0.017176
# authors_average_notation                  1.000000      0.152537
# rate_ratings                              0.152537      1.000000
# rate_ratings_authors                      0.633168      0.859322
#
#                           rate_ratings_authors
# bookID                               -0.015098
# average_rating                        0.441812
# isbn13                               -0.003132
# num_pages                             0.084742
# ratings_count                         0.088156
# text_reviews_count                    0.076840
# average_ratings_category              0.371738
# year                                 -0.037309
# month                                 0.030792
# authors_average_notation              0.633168
# rate_ratings                          0.859322
# rate_ratings_authors                  1.000000

# %%
train.average_ratings_category=pd.to_numeric(train.average_ratings_category)
train.corr()
# Out:
# /var/folders/5q/_mlmv_q11hd3pwylfnll66qr0000gn/T/ipykernel_17483/1748961638.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr()
#                             bookID  average_rating    isbn13  num_pages  \
# bookID                    1.000000       -0.020808  0.005606   0.001115
# average_rating           -0.020808        1.000000  0.002995   0.098645
# isbn13                    0.005606        0.002995  1.000000   0.023458
# num_pages                 0.001115        0.098645  0.023458   1.000000
# ratings_count            -0.063873        0.032696  0.006692   0.039468
# text_reviews_count       -0.071539        0.027505  0.008758   0.048794
# average_ratings_category -0.022530        0.789819  0.006532   0.088037
# year                      0.023282       -0.044939  0.002566  -0.002175
# month                     0.003994        0.030361 -0.003838   0.014070
# authors_average_notation -0.024468        0.637398 -0.016669   0.020707
#
#                           ratings_count  text_reviews_count  \
# bookID                        -0.063873           -0.071539
# average_rating                 0.032696            0.027505
# isbn13                         0.006692            0.008758
# num_pages                      0.039468            0.048794
# ratings_count                  1.000000            0.866476
# text_reviews_count             0.866476            1.000000
# average_ratings_category       0.020499            0.021794
# year                           0.044592            0.066464
# month                         -0.008199           -0.014160
# authors_average_notation       0.028677            0.027010
#
#                           average_ratings_category      year     month  \
# bookID                                   -0.022530  0.023282  0.003994
# average_rating                            0.789819 -0.044939  0.030361
# isbn13                                    0.006532  0.002566 -0.003838
# num_pages                                 0.088037 -0.002175  0.014070
# ratings_count                             0.020499  0.044592 -0.008199
# text_reviews_count                        0.021794  0.066464 -0.014160
# average_ratings_category                  1.000000 -0.044419  0.024098
# year                                     -0.044419  1.000000  0.037096
# month                                     0.024098  0.037096  1.000000
# authors_average_notation                  0.546854 -0.041674  0.031848
#
#                           authors_average_notation
# bookID                                   -0.024468
# average_rating                            0.637398
# isbn13                                   -0.016669
# num_pages                                 0.020707
# ratings_count                             0.028677
# text_reviews_count                        0.027010
# average_ratings_category                  0.546854
# year                                     -0.041674
# month                                     0.031848
# authors_average_notation                  1.000000

# %% [markdown]
# * Which authors wrote the most books ?

# %%
def get_sum_books(df):
    authors = df.copy()
    authors['authors'] = authors['authors'].astype(str)
    authors['authors'] = authors['authors'].apply(lambda x: x)
    authors['authors_split'] = authors['authors'].apply(lambda x: x.split('/'))
    authors = authors.explode('authors_split')
    most_books_written = authors.groupby('authors_split')['title'].count().sort_values(ascending=False)
    most_books_written = most_books_written.rename('nb_written_book').reset_index()
    
    return most_books_written

# %%
# Get the number of books written by group of authors
classement=get_sum_books(train)

# %%
#Analyse : 
# it will be interesting to capture the effect of each authors on the average-rating of the book. for example if we want to determine the number of book
#written by the pair J.K. Rowling/Mary GrandPre that will be interesting to add their respective number like 25+6=31.
#same if we can determine the average_authors_notation

# %% [markdown]
# * Who are the top 10 highly rated and the bottom 5 poorly rated authors?

# %%
import matplotlib.pyplot as plt
def plot_bar(classement,nb,head_or_tail):
  if head_or_tail=='head':
    classement=classement.sort_values(by='nb_written_book',ascending=False)
    # Tracer le diagramme à barres
    plt.bar(classement.authors_split[0:nb], classement.nb_written_book[0:nb])

    # Rotation des étiquettes
    plt.xticks(rotation='vertical')

    # Ajouter des titres et des étiquettes d'axe
    plt.xlabel('Authors')
    plt.ylabel('number of written books')
    plt.title('Top 10 of authors with the most wwritten book')

    # Afficher le diagramme
    plt.show()
  else :
    classement=classement.sort_values(by='nb_written_book',ascending=True)
    plt.bar(classement.authors_split[0:nb], classement.nb_written_book[0:nb])

    # Rotation des étiquettes
    plt.xticks(rotation='vertical')

    # Ajouter des titres et des étiquettes d'axe
    plt.xlabel('Authors')
    plt.ylabel('number of written books')
    plt.title('Top 10 of authors with the most wwritten book')

    # Afficher le diagramme
    plt.show()

# %%
plot_bar(classement,15,head_or_tail='head')
# Out:
# /var/folders/5q/_mlmv_q11hd3pwylfnll66qr0000gn/T/ipykernel_17483/2725631537.py:6: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.bar(classement.authors_split[0:nb], classement.nb_written_book[0:nb])

# %%
plot_bar(classement,15,head_or_tail='tail')
# Out:
# /var/folders/5q/_mlmv_q11hd3pwylfnll66qr0000gn/T/ipykernel_17483/2725631537.py:20: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.bar(classement.authors_split[0:nb], classement.nb_written_book[0:nb])

# %% [markdown]
# * Who are the top 10 highly rated and the bottom 5 poorly rated authors?

# %%
train.sort_values(by='average_rating',ascending=False)
train.sort_values(by='average_rating',ascending=False)
# Out:
#       bookID                                              title  \
# 4788   17224  The Diamond Color Meditation: Color Pathway to...
# 6184   23276                          Taxation of Mineral Rents
# 6247   23552                        The New Big Book of America
# 5023   18184  The Complete Theory Fun Factory: Music Theory ...
# 4933   17830  Bulgakov's the Master and Margarita: The Text ...
# ...      ...                                                ...
# 6839   25780               The Two Tocquevilles  Father and Son
# 5537   20157  McDougal Littell Science: Student Edition Grad...
# 8109   31166  The Earth and Its Peoples: A Global History  V...
# 7998   30651  The Art of Loving by Erich Fromm: A True Story...
# 9539   37877                               Mandala Sand Art Kit
#
#                                                 authors  average_rating  \
# 4788                                      John  Diamond            5.00
# 6184                                       Ross Garnaut            5.00
# 6247                               Todd Davis/Marc Frey            5.00
# 5023                    Ian        Martin/Katie Elliott            5.00
# 4933                                    Elena N. Mahlow            5.00
# ...                                                 ...             ...
# 6839                                        R.R. Palmer            2.00
# 5537                McDougal Littell/Douglas W. Carnine            2.00
# 8109  Richard W. Bulliet/Pamela Kyle Crossley/Steven...            2.00
# 7998                                       Lala Okamoto            1.67
# 9539                        Walter Foster Creative Team            1.00
#
#             isbn         isbn13 language_code  num_pages  ratings_count  \
# 4788  1890995525  9781890995522           eng       74.0              5
# 6184  0198284543  9780198284543           eng      350.0              1
# 6247  0762412631  9780762412631           eng       56.0              2
# 5023  0851621813  9780851621814           eng       96.0              1
# 4933  0533017424  9780533017423           eng      202.0              4
# ...          ...            ...           ...        ...            ...
# 6839  0691054959  9780691054957           eng      254.0              1
# 5537  0618615385  9780618615384           eng      972.0              3
# 8109  0618427694  9780618427697           eng      370.0              1
# 7998  4990327500  9784990327507           eng      227.0              3
# 9539  1560107669  9781560107668           eng        8.0              1
#
#       text_reviews_count publication_date                     publisher  \
# 4788                   3         2/1/2006         Square One Publishers
# 6184                   0       11/17/1983  Oxford University Press  USA
# 6247                   1        3/21/2002                 Courage Books
# 5023                   0         6/1/2004           Boosey & Hawkes Inc
# 4933                   0         1/1/1975                 Vantage Press
# ...                  ...              ...                           ...
# 6839                   0         4/1/1987    Princeton University Press
# 5537                   0        4/12/2005               McDougal Littel
# 8109                   1         2/9/2004              Cengage Learning
# 7998                   2       10/31/2006      Intercultural Publishing
# 9539                   0         1/1/2004      Walter Foster Publishing
#
#      average_ratings_category  year  month  \
# 4788                        3  2006      2
# 6184                        3  1983     11
# 6247                        3  2002      3
# 5023                        3  2004      6
# 4933                        3  1975      1
# ...                       ...   ...    ...
# 6839                        0  1987      4
# 5537                        0  2005      4
# 8109                        0  2004      2
# 7998                        0  2006     10
# 9539                        0  2004      1
#
#                                           authors_split  \
# 4788                                    [John  Diamond]
# 6184                                     [Ross Garnaut]
# 6247                            [Todd Davis, Marc Frey]
# 5023                 [Ian        Martin, Katie Elliott]
# 4933                                  [Elena N. Mahlow]
# ...                                                 ...
# 6839                                      [R.R. Palmer]
# 5537             [McDougal Littell, Douglas W. Carnine]
# 8109  [Richard W. Bulliet, Pamela Kyle Crossley, Ste...
# 7998                                     [Lala Okamoto]
# 9539                      [Walter Foster Creative Team]
#
#       authors_average_notation
# 4788                      4.13
# 6184                      3.85
# 6247                      3.90
# 5023                      3.84
# 4933                      3.84
# ...                        ...
# 6839                      3.96
# 5537                      3.80
# 8109                      3.43
# 7998                      2.50
# 9539                      3.99
#
# [8142 rows x 17 columns]

# %% [markdown]
# * How are books distributed across different languages ?

# %%
#analyse language_code
# eng/en-US/en-GB/en-CA ==> english written language. we will group them 
# The other language are not significantly present. 


# Data for the chart
labels = list(train.language_code.value_counts(normalize=True).sort_values(ascending=False).keys())
sizes = list(train.language_code.value_counts(normalize=True).sort_values(ascending=False)) # These should sum up to 100%

# Create a pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is circular.

# Add a title
plt.title('Structure of language')

# Show the chart
plt.show()

# %% [markdown]
# 94.6% of books have been written in english. the language won't bring any useful information in predicting average rating of books.
